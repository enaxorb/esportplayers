# %%
from SPARQLWrapper import SPARQLWrapper, JSON, TURTLE, XML, RDFXML
import pandas as pd
import numpy as np
import prince
import scipy.stats as stats


import matplotlib.pyplot as plt
import seaborn as sns
import pprint
import csv
import sys

import sqlite3 as sql

import time
import datetime
from dateutil import parser

from importlib import reload
from shutil import copyfile

sys.path.insert(0, '..')
sys.path.insert(0, '../..')


import sparql_functions as spqf

# %%
endpoint = "https://ag1zhv7l0xefmdtk.allegrograph.cloud/repositories/Esport"

query = """
PREFIX wd:      <http://www.wikidata.org/entity/>
PREFIX wdt:     <http://www.wikidata.org/prop/direct/>
PREFIX rdfs:    <http://www.w3.org/2000/01/rdf-schema#>
PREFIX xsd:  <http://www.w3.org/2001/XMLSchema#>


SELECT  ?item 
        (SAMPLE(STR(?itemLabel)) as ?itemLabel) 
        (MAX(?birthDate) as ?birthDate)  
        (MAX(?country) as ?country)
        ( GROUP_CONCAT(DISTINCT ?game; separator=", ") AS ?games )
WHERE {
    GRAPH <https://github.com/enaxorb/esportplayers/blob/main/graphs/wikidata-imported-data.md> {        
    # ?item wdt:P569 ?birthDate;
        wdt:P27 ?country;
        wdt:P2416 ?game;

    OPTIONAL {?item rdfs:label ?itemLabel .}
  }  
}
GROUP BY ?item
"""

# %%
qr = spqf.get_json_sparql_result(endpoint,query)
r = [l for l in spqf.sparql_result_to_list(qr)]

# %%
dfc = pd.DataFrame(r)
dfc.columns = ['personUri','itemLabel','birthYear','country','game']

# %%
#Nettoyage
def clean_id(s):
    if isinstance(s,str) and s.startswith('http'):
        return s.rsplit('/', 1) [-1]
    return s
dfc['country_clean'] = dfc['country'].apply(clean_id)

def clean_id(s):
    if isinstance(s,str) and s.startswith('http'):
        return s.rsplit('/', 1) [-1]
    return s
dfc['game_clean'] = dfc['game'].apply(clean_id)

# %%
#Tableau de contingence

tab_cont = pd.crosstab(dfc['country_clean'], dfc['game_clean'])
print(tab_cont.head())
# Out:
# game_clean     Q104830848  Q1052131  Q107247149  Q107424191  Q108054772  \
# country_clean
# Q1028                   0         0           0           0           0
# Q1054923                0         0           0           0           0
# Q1246                   0         0           0           0           0
# Q142                    1         1           0           0           0
# Q145                    0         0           0           0           0
#
# game_clean     Q10896671  Q111165107  Q112674290  Q11339103  Q1195150  ...  \
# country_clean                                                          ...
# Q1028                  0           0           0          0         0  ...
# Q1054923               0           0           0          0         0  ...
# Q1246                  0           1           0          0         0  ...
# Q142                   0           0           0          0         1  ...
# Q145                   0           0           0          0         0  ...
#
# game_clean     Q85760410  Q86919275  Q869960  Q870981  Q87416343  Q913536  \
# country_clean
# Q1028                  0          1        0        0          0        0
# Q1054923               0          0        0        0          0        0
# Q1246                  0          0        0        0          0        0
# Q142                   0          0        0        0          0        0
# Q145                   0          0        0        0          0        1
#
# game_clean     Q914286  Q91573142  Q939447  Q96416457
# country_clean
# Q1028                0          0        0          0
# Q1054923             0          0        0          0
# Q1246                0          0        0          0
# Q142                 0          0        0          0
# Q145                 0          0        0          0
#
# [5 rows x 121 columns]

# %%
#chicarré
chi2, p, dof, expected = chi2_contingency(tab_cont)
if p < 0.06:
    print("dépendance significative")
else:
    print("Pas de dépendance")
# Out:
# dépendance significative

# %%
#Analyse factorielle

af = prince.CA(n_components=2)
af =af.fit(tab_cont)
lig_coord = af.row_coordinates(tab_cont)
col_coord = af.column_coordinates(tab_cont)

lig_coord['label'] = row_coords.index
lig_coord['type']  = 'Pays'
col_coord['label'] = col_coords.index
col_coord['type']  = 'Jeux'

dfplot = pd.concat([lig_coord, col_coord])

# %%
#Visualisation
plt.figure(figsize=(12, 10))
plt.scatter(
    lig_coord[0], lig_coord[1],
    label="Pays", color="blue", s = 100
)
plt.scatter(
    col_coord[0], col_coord[1],
    label="Jeux", color="orange", s=40
)
plt.axhline(0, color='grey', linestyle='--', linewidth=0.7)
plt.axvline(0, color='grey', linestyle='--', linewidth=0.7)
plt.title("Relations entre les pays et les jeux des joueurs professionnels")
plt.legend()
plt.show()
